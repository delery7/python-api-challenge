# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
# !pip install citipy

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# weather_api_key

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities_df=pd.DataFrame(cities)
cities_df.columns=['City']
cities_df.head(5)
# Out:
#          City
# 0     ushuaia
# 1     sorland
# 2  codrington
# 3       tiksi
# 4      murgab

# %%
# Add columns for lat, lng, airport name, airport address, airport rating
# Note that we used "" to specify initial entry.
cities_df["Lat"] = ""
cities_df["Lng"] = ""
cities_df["Max Temp"] = ""
cities_df["Humidity"] = ""
cities_df["Cloudiness"] = ""
cities_df["Wind Speed"] = ""
cities_df["Country"] = ""
cities_df["Date"] = ""
cities_df.head()
# Out:
#          City Lat Lng Max Temp Humidity Cloudiness Wind Speed Country Date
# 0     ushuaia
# 1     sorland
# 2  codrington
# 3       tiksi
# 4      murgab

# %%
# # Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
city='cape town'
# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

response = requests.get(query_url + city).json()
# print(json.dumps(response, indent=4, sort_keys=True))
# lat= response["clouds"]['all']
# lat

# %%
for index, row in cities_df.iterrows():
    query_url = f"{url}appid={weather_api_key}&units={units}&q="
    city=row["City"]
   
      # make request
    response = requests.get(query_url + city).json()
    
    try:           
        cities_df.loc[index, "Lat"] = response["coord"]["lat"]
        cities_df.loc[index, "Lng"] = response["coord"]["lon"]
        cities_df.loc[index, "Max Temp"]= response["main"]["temp_max"]
        cities_df.loc[index, "Humidity"] = response["main"]["humidity"]
        cities_df.loc[index, "Cloudiness"] = response["clouds"]["all"]
        cities_df.loc[index, "Wind Speed"] = response["wind"]["speed"]
        cities_df.loc[index, "Country"] = response["sys"]["country"]
        cities_df.loc[index, "Date"] = response["dt"]
        print(f'Processing Record {index} of Set 1 | {city}')
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Visualize to confirm lat lng appear
cities_df.head()
# Out:
# Processing Record 0 of Set 1 | ushuaia
# Processing Record 1 of Set 1 | sorland
# Processing Record 2 of Set 1 | codrington
# Processing Record 3 of Set 1 | tiksi
# Processing Record 4 of Set 1 | murgab
# Processing Record 5 of Set 1 | nantucket
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | aksarka
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | yinchuan
# Missing field/result... skipping.
# Processing Record 13 of Set 1 | praia da vitoria
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | port macquarie
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | broken hill
# Processing Record 19 of Set 1 | isla mujeres
# Processing Record 20 of Set 1 | najran
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | plouzane
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | carora
# Processing Record 25 of Set 1 | mattru
# Processing Record 26 of Set 1 | avarua
# Missing field/result... skipping.
# Processing Record 28 of Set 1 | turtas
# Processing Record 29 of Set 1 | samarai
# Processing Record 30 of Set 1 | cape town
# Missing field/result... skipping.
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | mahebourg
# Processing Record 34 of Set 1 | yulara
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | bayanday
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | ponta do sol
# Processing Record 39 of Set 1 | lasa
# Processing Record 40 of Set 1 | nanortalik
# Processing Record 41 of Set 1 | karla
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | kloulklubed
# Processing Record 44 of Set 1 | pisco
# Processing Record 45 of Set 1 | isangel
# Processing Record 46 of Set 1 | cap malheureux
# Processing Record 47 of Set 1 | bengkulu
# Processing Record 48 of Set 1 | north platte
# Processing Record 49 of Set 1 | nauta
# Processing Record 50 of Set 1 | mount isa
# Processing Record 51 of Set 1 | ostrovnoy
# Missing field/result... skipping.
# Processing Record 53 of Set 1 | vila velha
# Processing Record 54 of Set 1 | vaini
# Processing Record 55 of Set 1 | kota belud
# Processing Record 56 of Set 1 | nalut
# Processing Record 57 of Set 1 | fortuna
# Processing Record 58 of Set 1 | kapaa
# Processing Record 59 of Set 1 | henties bay
# Processing Record 60 of Set 1 | namibe
# Processing Record 61 of Set 1 | yurovka
# Processing Record 62 of Set 1 | jamestown
# Processing Record 63 of Set 1 | jibuti
# Processing Record 64 of Set 1 | mayo
# Processing Record 65 of Set 1 | matagami
# Processing Record 66 of Set 1 | yumen
# Processing Record 67 of Set 1 | matara
# Processing Record 68 of Set 1 | mar del plata
# Missing field/result... skipping.
# Processing Record 70 of Set 1 | pathanamthitta
# Processing Record 71 of Set 1 | sakakah
# Processing Record 72 of Set 1 | nyimba
# Processing Record 73 of Set 1 | upernavik
# Processing Record 74 of Set 1 | faanui
# Processing Record 75 of Set 1 | port-cartier
# Processing Record 76 of Set 1 | karachi
# Processing Record 77 of Set 1 | rikitea
# Processing Record 78 of Set 1 | saint-philippe
# Processing Record 79 of Set 1 | cortez
# Processing Record 80 of Set 1 | butaritari
# Processing Record 81 of Set 1 | bambous virieux
# Processing Record 82 of Set 1 | guerrero negro
# Processing Record 83 of Set 1 | margate
# Processing Record 84 of Set 1 | new norfolk
# Processing Record 85 of Set 1 | yellowknife
# Missing field/result... skipping.
# Processing Record 87 of Set 1 | poum
# Processing Record 88 of Set 1 | yar-sale
# Processing Record 89 of Set 1 | arraial do cabo
# Processing Record 90 of Set 1 | goderich
# Processing Record 91 of Set 1 | ghazipur
# Processing Record 92 of Set 1 | port alfred
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 95 of Set 1 | poltavka
# Missing field/result... skipping.
# Processing Record 97 of Set 1 | carnarvon
# Processing Record 98 of Set 1 | mataura
# Processing Record 99 of Set 1 | makakilo city
# Processing Record 100 of Set 1 | fort nelson
# Processing Record 101 of Set 1 | prieska
# Processing Record 102 of Set 1 | inongo
# Processing Record 103 of Set 1 | bethel
# Missing field/result... skipping.
# Processing Record 105 of Set 1 | sinnamary
# Processing Record 106 of Set 1 | ribeira grande
# Processing Record 107 of Set 1 | torbay
# Processing Record 108 of Set 1 | revelstoke
# Processing Record 109 of Set 1 | tazovskiy
# Processing Record 110 of Set 1 | leningradskiy
# Missing field/result... skipping.
# Processing Record 112 of Set 1 | palana
# Processing Record 113 of Set 1 | noumea
# Processing Record 114 of Set 1 | qaanaaq
# Processing Record 115 of Set 1 | shimoda
# Processing Record 116 of Set 1 | rokiskis
# Processing Record 117 of Set 1 | nikolskoye
# Processing Record 118 of Set 1 | balkanabat
# Processing Record 119 of Set 1 | hasaki
# Processing Record 120 of Set 1 | harare
# Processing Record 121 of Set 1 | cayenne
# Processing Record 122 of Set 1 | orcopampa
# Processing Record 123 of Set 1 | bluff
# Processing Record 124 of Set 1 | kaitangata
# Processing Record 125 of Set 1 | gat
# Processing Record 126 of Set 1 | airai
# Processing Record 127 of Set 1 | wau
# Processing Record 128 of Set 1 | hamilton
# Processing Record 129 of Set 1 | severo-kurilsk
# Processing Record 130 of Set 1 | delta del tigre
# Missing field/result... skipping.
# Processing Record 132 of Set 1 | hella
# Processing Record 133 of Set 1 | imbituba
# Processing Record 134 of Set 1 | baykit
# Processing Record 135 of Set 1 | lagoa
# Processing Record 136 of Set 1 | port elizabeth
# Processing Record 137 of Set 1 | novyy yegorlyk
# Processing Record 138 of Set 1 | tautira
# Missing field/result... skipping.
# Processing Record 140 of Set 1 | mayya
# Processing Record 141 of Set 1 | kysucke nove mesto
# Processing Record 142 of Set 1 | georgetown
# Processing Record 143 of Set 1 | mount gambier
# Processing Record 144 of Set 1 | amursk
# Processing Record 145 of Set 1 | la ronge
# Processing Record 146 of Set 1 | tuktoyaktuk
# Missing field/result... skipping.
# Processing Record 148 of Set 1 | alta floresta
# Processing Record 149 of Set 1 | marawi
# Processing Record 150 of Set 1 | padang
# Processing Record 151 of Set 1 | provideniya
# Processing Record 152 of Set 1 | thompson
# Processing Record 153 of Set 1 | saldanha
# Processing Record 154 of Set 1 | hambantota
# Processing Record 155 of Set 1 | kampong chhnang
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 158 of Set 1 | tasiilaq
# Processing Record 159 of Set 1 | atar
# Processing Record 160 of Set 1 | linhares
# Processing Record 161 of Set 1 | vardo
# Processing Record 162 of Set 1 | lekoni
# Processing Record 163 of Set 1 | peniche
# Processing Record 164 of Set 1 | moose factory
# Processing Record 165 of Set 1 | christchurch
# Processing Record 166 of Set 1 | san patricio
# Processing Record 167 of Set 1 | huarmey
# Processing Record 168 of Set 1 | ondjiva
# Processing Record 169 of Set 1 | lima
# Processing Record 170 of Set 1 | benghazi
# Processing Record 171 of Set 1 | muzhi
# Processing Record 172 of Set 1 | manokwari
# Processing Record 173 of Set 1 | cabedelo
# Processing Record 174 of Set 1 | zhigansk
# Processing Record 175 of Set 1 | santa fe
# Processing Record 176 of Set 1 | mackay
# Processing Record 177 of Set 1 | san cristobal
# Processing Record 178 of Set 1 | dunedin
# Processing Record 179 of Set 1 | castro
# Processing Record 180 of Set 1 | huilong
# Processing Record 181 of Set 1 | lloydminster
# Processing Record 182 of Set 1 | ginir
# Processing Record 183 of Set 1 | jumla
# Processing Record 184 of Set 1 | wajima
# Processing Record 185 of Set 1 | wanning
# Processing Record 186 of Set 1 | saint-pierre
# Processing Record 187 of Set 1 | itarema
# Processing Record 188 of Set 1 | trabzon
# Processing Record 189 of Set 1 | florianopolis
# Processing Record 190 of Set 1 | zalantun
# Processing Record 191 of Set 1 | pimentel
# Missing field/result... skipping.
# Processing Record 193 of Set 1 | grindavik
# Processing Record 194 of Set 1 | viedma
# Processing Record 195 of Set 1 | east london
# Processing Record 196 of Set 1 | sokoni
# Processing Record 197 of Set 1 | puerto penasco
# Processing Record 198 of Set 1 | westport
# Processing Record 199 of Set 1 | yenagoa
# Processing Record 200 of Set 1 | deputatskiy
# Processing Record 201 of Set 1 | nioki
# Processing Record 202 of Set 1 | jaitaran
# Processing Record 203 of Set 1 | beloha
# Processing Record 204 of Set 1 | flinders
# Processing Record 205 of Set 1 | turan
# Processing Record 206 of Set 1 | fairbanks
# Processing Record 207 of Set 1 | asuncion
# Processing Record 208 of Set 1 | skjervoy
# Processing Record 209 of Set 1 | ancud
# Processing Record 210 of Set 1 | samana
# Processing Record 211 of Set 1 | touros
# Processing Record 212 of Set 1 | lebu
# Processing Record 213 of Set 1 | minab
# Processing Record 214 of Set 1 | norman wells
# Processing Record 215 of Set 1 | lata
# Processing Record 216 of Set 1 | sitka
# Processing Record 217 of Set 1 | katubao
# Processing Record 218 of Set 1 | aklavik
# Processing Record 219 of Set 1 | strezhevoy
# Processing Record 220 of Set 1 | yabelo
# Processing Record 221 of Set 1 | vila
# Processing Record 222 of Set 1 | mandiana
# Processing Record 223 of Set 1 | karratha
# Processing Record 224 of Set 1 | longyearbyen
# Processing Record 225 of Set 1 | ugoofaaru
# Processing Record 226 of Set 1 | bathsheba
# Processing Record 227 of Set 1 | grand gaube
# Processing Record 228 of Set 1 | wadowice
# Processing Record 229 of Set 1 | pomabamba
# Processing Record 230 of Set 1 | balakhta
# Processing Record 231 of Set 1 | comodoro rivadavia
# Processing Record 232 of Set 1 | bin qirdan
# Processing Record 233 of Set 1 | straumen
# Processing Record 234 of Set 1 | madimba
# Processing Record 235 of Set 1 | polczyn-zdroj
# Processing Record 236 of Set 1 | taman
# Processing Record 237 of Set 1 | srandakan
# Missing field/result... skipping.
# Processing Record 239 of Set 1 | acapulco
# Processing Record 240 of Set 1 | ola
# Processing Record 241 of Set 1 | porto novo
# Processing Record 242 of Set 1 | waddan
# Processing Record 243 of Set 1 | hilo
# Processing Record 244 of Set 1 | kismayo
# Processing Record 245 of Set 1 | amurzet
# Processing Record 246 of Set 1 | salgueiro
# Processing Record 247 of Set 1 | ternate
# Processing Record 248 of Set 1 | hithadhoo
# Processing Record 249 of Set 1 | upington
# Missing field/result... skipping.
# Processing Record 251 of Set 1 | pakenham
# Processing Record 252 of Set 1 | ballina
# Processing Record 253 of Set 1 | ahipara
# Processing Record 254 of Set 1 | kalmunai
# Missing field/result... skipping.
# Processing Record 256 of Set 1 | kyra
# Missing field/result... skipping.
# Processing Record 258 of Set 1 | victoria
# Processing Record 259 of Set 1 | lethem
# Missing field/result... skipping.
# Processing Record 261 of Set 1 | portobelo
# Processing Record 262 of Set 1 | qaqortoq
# Processing Record 263 of Set 1 | fare
# Processing Record 264 of Set 1 | te anau
# Processing Record 265 of Set 1 | vanimo
# Processing Record 266 of Set 1 | keetmanshoop
# Missing field/result... skipping.
# Processing Record 268 of Set 1 | mabaruma
# Processing Record 269 of Set 1 | santarem
# Processing Record 270 of Set 1 | hovd
# Processing Record 271 of Set 1 | formosa
# Processing Record 272 of Set 1 | narsaq
# Processing Record 273 of Set 1 | bandarbeyla
# Processing Record 274 of Set 1 | dubai
# Processing Record 275 of Set 1 | adrar
# Missing field/result... skipping.
# Processing Record 277 of Set 1 | dudinka
# Processing Record 278 of Set 1 | taoudenni
# Processing Record 279 of Set 1 | stepnogorsk
# Processing Record 280 of Set 1 | evensk
# Processing Record 281 of Set 1 | sungaipenuh
# Processing Record 282 of Set 1 | los llanos de aridane
# Processing Record 283 of Set 1 | souillac
# Processing Record 284 of Set 1 | champerico
# Processing Record 285 of Set 1 | meulaboh
# Processing Record 286 of Set 1 | labuhan
# Processing Record 287 of Set 1 | tuatapere
# Processing Record 288 of Set 1 | tymovskoye
# Processing Record 289 of Set 1 | richards bay
# Processing Record 290 of Set 1 | pechenga
# Processing Record 291 of Set 1 | klaksvik
# Missing field/result... skipping.
# Processing Record 293 of Set 1 | progreso
# Processing Record 294 of Set 1 | bratsk
# Processing Record 295 of Set 1 | zuidhorn
# Processing Record 296 of Set 1 | katsuura
# Processing Record 297 of Set 1 | shuangcheng
# Missing field/result... skipping.
# Processing Record 299 of Set 1 | calvia
# Processing Record 300 of Set 1 | kruisfontein
# Processing Record 301 of Set 1 | laiyang
# Processing Record 302 of Set 1 | sebring
# Processing Record 303 of Set 1 | pyapon
# Missing field/result... skipping.
# Processing Record 305 of Set 1 | saint paul
# Processing Record 306 of Set 1 | chilia veche
# Processing Record 307 of Set 1 | sao joao da barra
# Processing Record 308 of Set 1 | ilulissat
# Processing Record 309 of Set 1 | gizo
# Missing field/result... skipping.
# Processing Record 311 of Set 1 | aleksandrovskiy zavod
# Processing Record 312 of Set 1 | aykhal
# Processing Record 313 of Set 1 | qiyang
# Processing Record 314 of Set 1 | opuwo
# Processing Record 315 of Set 1 | kavaratti
# Processing Record 316 of Set 1 | ankazobe
# Processing Record 317 of Set 1 | axim
# Processing Record 318 of Set 1 | iranshahr
# Processing Record 319 of Set 1 | kharovsk
# Processing Record 320 of Set 1 | constitucion
# Processing Record 321 of Set 1 | mecca
# Processing Record 322 of Set 1 | karonga
# Processing Record 323 of Set 1 | kaoma
# Processing Record 324 of Set 1 | vila franca do campo
# Processing Record 325 of Set 1 | birzai
# Processing Record 326 of Set 1 | zile
# Processing Record 327 of Set 1 | gazli
# Processing Record 328 of Set 1 | chara
# Missing field/result... skipping.
# Processing Record 330 of Set 1 | menomonie
# Processing Record 331 of Set 1 | bom jardim
# Processing Record 332 of Set 1 | dorsten
# Missing field/result... skipping.
# Processing Record 334 of Set 1 | vao
# Processing Record 335 of Set 1 | warmbad
# Processing Record 336 of Set 1 | hami
# Processing Record 337 of Set 1 | cherskiy
# Processing Record 338 of Set 1 | oksfjord
# Processing Record 339 of Set 1 | altar
# Processing Record 340 of Set 1 | rocha
# Processing Record 341 of Set 1 | sao filipe
# Processing Record 342 of Set 1 | alyangula
# Processing Record 343 of Set 1 | zhigalovo
# Processing Record 344 of Set 1 | zhanaozen
# Processing Record 345 of Set 1 | senanga
# Processing Record 346 of Set 1 | coruripe
# Missing field/result... skipping.
# Processing Record 348 of Set 1 | jacareacanga
# Processing Record 349 of Set 1 | cidreira
# Processing Record 350 of Set 1 | verkhoshizhemye
# Missing field/result... skipping.
# Processing Record 352 of Set 1 | mbuji-mayi
# Processing Record 353 of Set 1 | inhambane
# Processing Record 354 of Set 1 | coquimbo
# Processing Record 355 of Set 1 | ludvika
# Processing Record 356 of Set 1 | datong
# Processing Record 357 of Set 1 | kysyl-syr
# Processing Record 358 of Set 1 | chuy
# Processing Record 359 of Set 1 | vinh long
# Processing Record 360 of Set 1 | lokosovo
# Processing Record 361 of Set 1 | calvinia
# Processing Record 362 of Set 1 | mandya
# Processing Record 363 of Set 1 | antigonish
# Processing Record 364 of Set 1 | waipawa
# Processing Record 365 of Set 1 | port hedland
# Processing Record 366 of Set 1 | port lincoln
# Missing field/result... skipping.
# Processing Record 368 of Set 1 | koulikoro
# Processing Record 369 of Set 1 | alice springs
# Processing Record 370 of Set 1 | asau
# Processing Record 371 of Set 1 | cabo san lucas
# Processing Record 372 of Set 1 | boguchany
# Processing Record 373 of Set 1 | saint-francois
# Processing Record 374 of Set 1 | high level
# Processing Record 375 of Set 1 | north bend
# Processing Record 376 of Set 1 | tecoanapa
# Processing Record 377 of Set 1 | nikolsk
# Processing Record 378 of Set 1 | ust-tsilma
# Processing Record 379 of Set 1 | paamiut
# Processing Record 380 of Set 1 | fershampenuaz
# Processing Record 381 of Set 1 | denpasar
# Processing Record 382 of Set 1 | aksu
# Processing Record 383 of Set 1 | taperoa
# Processing Record 384 of Set 1 | nara
# Processing Record 385 of Set 1 | trzebiatow
# Missing field/result... skipping.
# Processing Record 387 of Set 1 | mercedes
# Processing Record 388 of Set 1 | dicabisagan
# Processing Record 389 of Set 1 | port blair
# Processing Record 390 of Set 1 | baghdad
# Processing Record 391 of Set 1 | meaford
# Processing Record 392 of Set 1 | port hawkesbury
# Processing Record 393 of Set 1 | slonim
# Processing Record 394 of Set 1 | launceston
# Processing Record 395 of Set 1 | marzuq
# Processing Record 396 of Set 1 | kavieng
# Processing Record 397 of Set 1 | rio gallegos
# Processing Record 398 of Set 1 | okakarara
# Processing Record 399 of Set 1 | bentiu
# Processing Record 400 of Set 1 | svetlaya
# Processing Record 401 of Set 1 | russell
# Processing Record 402 of Set 1 | panguna
# Processing Record 403 of Set 1 | daru
# Processing Record 404 of Set 1 | payo
# Processing Record 405 of Set 1 | ocampo
# Processing Record 406 of Set 1 | pangnirtung
# Processing Record 407 of Set 1 | yuzhno-kurilsk
# Missing field/result... skipping.
# Processing Record 409 of Set 1 | lorengau
# Processing Record 410 of Set 1 | lokoja
# Processing Record 411 of Set 1 | chokurdakh
# Processing Record 412 of Set 1 | buraydah
# Processing Record 413 of Set 1 | abu dhabi
# Processing Record 414 of Set 1 | ponta delgada
# Processing Record 415 of Set 1 | halifax
# Processing Record 416 of Set 1 | ust-kuyga
# Processing Record 417 of Set 1 | xining
# Processing Record 418 of Set 1 | laguna
# Processing Record 419 of Set 1 | kisangani
# Missing field/result... skipping.
# Processing Record 421 of Set 1 | nicoya
# Processing Record 422 of Set 1 | esperance
# Processing Record 423 of Set 1 | kindu
# Processing Record 424 of Set 1 | sola
# Missing field/result... skipping.
# Processing Record 426 of Set 1 | azovo
# Processing Record 427 of Set 1 | zarubino
# Missing field/result... skipping.
# Processing Record 429 of Set 1 | hastings
# Missing field/result... skipping.
# Processing Record 431 of Set 1 | saskylakh
# Processing Record 432 of Set 1 | haines junction
# Processing Record 433 of Set 1 | mangai
# Missing field/result... skipping.
# Processing Record 435 of Set 1 | zhukovskiy
# Processing Record 436 of Set 1 | gunjur
# Processing Record 437 of Set 1 | kangaatsiaq
# Processing Record 438 of Set 1 | talcahuano
# Processing Record 439 of Set 1 | alofi
# Processing Record 440 of Set 1 | tongliao
# Processing Record 441 of Set 1 | raudeberg
# Processing Record 442 of Set 1 | polis
# Processing Record 443 of Set 1 | bayevo
# Processing Record 444 of Set 1 | naze
# Processing Record 445 of Set 1 | muros
# Processing Record 446 of Set 1 | zima
# Processing Record 447 of Set 1 | redmond
# Processing Record 448 of Set 1 | hokitika
# Processing Record 449 of Set 1 | kahului
# Processing Record 450 of Set 1 | santa isabel do rio negro
# Processing Record 451 of Set 1 | clyde river
# Processing Record 452 of Set 1 | palmer
# Processing Record 453 of Set 1 | benjamin aceval
# Processing Record 454 of Set 1 | port keats
# Processing Record 455 of Set 1 | bonthe
# Processing Record 456 of Set 1 | west odessa
# Processing Record 457 of Set 1 | nouadhibou
# Missing field/result... skipping.
# Processing Record 459 of Set 1 | mao
# Processing Record 460 of Set 1 | norden
# Processing Record 461 of Set 1 | hirara
# Processing Record 462 of Set 1 | arecibo
# Processing Record 463 of Set 1 | portland
# Processing Record 464 of Set 1 | xai-xai
# Processing Record 465 of Set 1 | bernay
# Processing Record 466 of Set 1 | talnakh
# Processing Record 467 of Set 1 | cody
# Missing field/result... skipping.
# Processing Record 469 of Set 1 | grahamstown
# Processing Record 470 of Set 1 | trelew
# Processing Record 471 of Set 1 | nome
# Processing Record 472 of Set 1 | bam
# Processing Record 473 of Set 1 | gillette
# Processing Record 474 of Set 1 | salalah
# Processing Record 475 of Set 1 | new baltimore
# Processing Record 476 of Set 1 | tagusao
# Processing Record 477 of Set 1 | pasni
# Processing Record 478 of Set 1 | muhos
# Processing Record 479 of Set 1 | lavrentiya
# Processing Record 480 of Set 1 | golfito
# Processing Record 481 of Set 1 | vung tau
# Processing Record 482 of Set 1 | sibolga
# Processing Record 483 of Set 1 | eenhana
# Processing Record 484 of Set 1 | santa rita
# Processing Record 485 of Set 1 | ypsilanti
# Processing Record 486 of Set 1 | caravelas
# Processing Record 487 of Set 1 | severnyy
# Processing Record 488 of Set 1 | sal rei
# Processing Record 489 of Set 1 | tevriz
# Processing Record 490 of Set 1 | ewa beach
# Processing Record 491 of Set 1 | caceres
# Processing Record 492 of Set 1 | brae
# Missing field/result... skipping.
# Processing Record 494 of Set 1 | peruibe
# Processing Record 495 of Set 1 | orlik
# Processing Record 496 of Set 1 | almeirim
# Processing Record 497 of Set 1 | kristianstad
# Processing Record 498 of Set 1 | sharan
# Processing Record 499 of Set 1 | linares
# Processing Record 500 of Set 1 | negombo
# Processing Record 501 of Set 1 | francistown
# Processing Record 502 of Set 1 | pacific grove
# Missing field/result... skipping.
# Processing Record 504 of Set 1 | port hardy
# Missing field/result... skipping.
# Processing Record 506 of Set 1 | shelburne
# Processing Record 507 of Set 1 | erdenet
# Processing Record 508 of Set 1 | roald
# Processing Record 509 of Set 1 | mahon
# Processing Record 510 of Set 1 | dalhousie
# Processing Record 511 of Set 1 | chipinge
# Processing Record 512 of Set 1 | luderitz
# Processing Record 513 of Set 1 | comendador
# Missing field/result... skipping.
# Processing Record 515 of Set 1 | noshiro
# Processing Record 516 of Set 1 | verkhniy avzyan
# Processing Record 517 of Set 1 | terney
# Processing Record 518 of Set 1 | fort smith
# Processing Record 519 of Set 1 | visby
# Processing Record 520 of Set 1 | mana
# Processing Record 521 of Set 1 | neuquen
# Processing Record 522 of Set 1 | udon thani
# Processing Record 523 of Set 1 | napasar
# Processing Record 524 of Set 1 | shingu
# Processing Record 525 of Set 1 | kaka
# Processing Record 526 of Set 1 | zig
# Processing Record 527 of Set 1 | kovdor
# Processing Record 528 of Set 1 | falam
# Processing Record 529 of Set 1 | bad hersfeld
# Processing Record 530 of Set 1 | liwale
# Processing Record 531 of Set 1 | ketchikan
# Processing Record 532 of Set 1 | nizwa
# Processing Record 533 of Set 1 | port-gentil
# Processing Record 534 of Set 1 | srednekolymsk
# Missing field/result... skipping.
# Processing Record 536 of Set 1 | ngama
# Processing Record 537 of Set 1 | along
# Processing Record 538 of Set 1 | banjar
# Processing Record 539 of Set 1 | mackenzie
# Processing Record 540 of Set 1 | aksha
# Processing Record 541 of Set 1 | great bend
# Processing Record 542 of Set 1 | mehamn
# Processing Record 543 of Set 1 | chulucanas
# Processing Record 544 of Set 1 | rosetta
# Processing Record 545 of Set 1 | havre-saint-pierre
# Processing Record 546 of Set 1 | jinan
# Processing Record 547 of Set 1 | muramatsu
# Processing Record 548 of Set 1 | tezu
# Processing Record 549 of Set 1 | san felipe
# Processing Record 550 of Set 1 | saint-louis
# Processing Record 551 of Set 1 | talara
# Processing Record 552 of Set 1 | dingle
# Processing Record 553 of Set 1 | sirjan
# Processing Record 554 of Set 1 | aras
# Processing Record 555 of Set 1 | douglas
# Processing Record 556 of Set 1 | severo-yeniseyskiy
# Processing Record 557 of Set 1 | kakching
# Processing Record 558 of Set 1 | ossora
# Processing Record 559 of Set 1 | chernyshevskiy
# Processing Record 560 of Set 1 | vostok
# Processing Record 561 of Set 1 | tanhacu
# Processing Record 562 of Set 1 | kadi
# Processing Record 563 of Set 1 | luau
# Processing Record 564 of Set 1 | kurilsk
# Processing Record 565 of Set 1 | kudahuvadhoo
# Processing Record 566 of Set 1 | udachnyy
# Processing Record 567 of Set 1 | copiapo
# Processing Record 568 of Set 1 | oulainen
# Processing Record 569 of Set 1 | bull savanna
# Missing field/result... skipping.
# Processing Record 571 of Set 1 | abadiania
# Missing field/result... skipping.
# Processing Record 573 of Set 1 | synya
# Processing Record 574 of Set 1 | la paz
# Processing Record 575 of Set 1 | berja
# Processing Record 576 of Set 1 | talaya
# Processing Record 577 of Set 1 | san rafael del sur
# Missing field/result... skipping.
# Processing Record 579 of Set 1 | bluefields
# Processing Record 580 of Set 1 | naftalan
# Processing Record 581 of Set 1 | bandikui
# Processing Record 582 of Set 1 | hervey bay
# Processing Record 583 of Set 1 | olafsvik
# Processing Record 584 of Set 1 | buala
# Processing Record 585 of Set 1 | dzerzhinskoye
# Processing Record 586 of Set 1 | armidale
# Processing Record 587 of Set 1 | acarau
# Processing Record 588 of Set 1 | boyuibe
# Processing Record 589 of Set 1 | anloga
# Processing Record 590 of Set 1 | povenets
# Processing Record 591 of Set 1 | mutsu
# Processing Record 592 of Set 1 | kargat
# Processing Record 593 of Set 1 | la rioja
# Processing Record 594 of Set 1 | saint anthony
# Processing Record 595 of Set 1 | svetlyy
# Processing Record 596 of Set 1 | carauari
#          City      Lat      Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0     ushuaia    -54.8    -68.3     39.2       81         75       4.61
# 1     sorland   67.667  12.6934    36.32       80        100       14.2
# 2  codrington -38.2667  141.967    60.66       63        100      19.01
# 3       tiksi  71.6872  128.869   -36.74       83        100       4.09
# 4      murgab  37.4966  61.9714     28.4       80          0       8.12
#
#   Country        Date
# 0      AR  1611709682
# 1      NO  1611709931
# 2      AU  1611709957
# 3      RU  1611709957
# 4      TM  1611709725

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.to_csv("City_data.csv")
cities_df.head(5)
# cities_df.to_numeric("Lat")
# Out:
#          City      Lat      Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0     ushuaia    -54.8    -68.3     39.2       81         75       4.61
# 1     sorland   67.667  12.6934    36.32       80        100       14.2
# 2  codrington -38.2667  141.967    60.66       63        100      19.01
# 3       tiksi  71.6872  128.869   -36.74       83        100       4.09
# 4      murgab  37.4966  61.9714     28.4       80          0       8.12
#
#   Country        Date
# 0      AR  1611709682
# 1      NO  1611709931
# 2      AU  1611709957
# 3      RU  1611709957
# 4      TM  1611709725

# %%
# df['DataFrame Column'] = pd.to_numeric(df['DataFrame Column'],errors='coerce')
cities_df['Lat']=pd.to_numeric(cities_df['Lat'],errors='coerce')
cities_df['Lng']=pd.to_numeric(cities_df['Lng'],errors='coerce')
cities_df['Max Temp']=pd.to_numeric(cities_df['Max Temp'],errors='coerce')
cities_df['Humidity']=pd.to_numeric(cities_df['Humidity'],errors='coerce')
cities_df['Cloudiness']=pd.to_numeric(cities_df['Cloudiness'],errors='coerce')
cities_df['Wind Speed']=pd.to_numeric(cities_df['Wind Speed'],errors='coerce')
cities_df['Date']=pd.to_numeric(cities_df['Date'],errors='coerce')
# cities_df.dtypes

# %%
cities_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  547.000000  547.000000  547.000000  547.000000  547.000000  547.000000
# mean    19.906690   20.972735   47.253601   76.835466   57.703839    8.540073
# std     34.161686   88.846808   33.566373   17.847912   41.316655    6.104314
# min    -54.800000 -175.200000  -54.400000   15.000000    0.000000    0.690000
# 25%     -8.741650  -57.562100   28.200000   70.000000    5.000000    3.690000
# 50%     24.483300   24.800000   59.000000   81.000000   75.000000    7.070000
# 75%     49.663900   98.116150   74.300000   90.000000  100.000000   11.990000
# max     78.218600  178.416700   96.800000  100.000000  100.000000   32.950000
#
#                Date
# count  5.470000e+02
# mean   1.611710e+09
# std    9.366600e+01
# min    1.611710e+09
# 25%    1.611710e+09
# 50%    1.611710e+09
# 75%    1.611710e+09
# max    1.611710e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
index_names = cities_df[(cities_df['Humidity'] > 100)].index
index_names
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
cities_clean=cities_df.drop(index_names, inplace = False)
cities_clean.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  547.000000  547.000000  547.000000  547.000000  547.000000  547.000000
# mean    19.906690   20.972735   47.253601   76.835466   57.703839    8.540073
# std     34.161686   88.846808   33.566373   17.847912   41.316655    6.104314
# min    -54.800000 -175.200000  -54.400000   15.000000    0.000000    0.690000
# 25%     -8.741650  -57.562100   28.200000   70.000000    5.000000    3.690000
# 50%     24.483300   24.800000   59.000000   81.000000   75.000000    7.070000
# 75%     49.663900   98.116150   74.300000   90.000000  100.000000   11.990000
# max     78.218600  178.416700   96.800000  100.000000  100.000000   32.950000
#
#                Date
# count  5.470000e+02
# mean   1.611710e+09
# std    9.366600e+01
# min    1.611710e+09
# 25%    1.611710e+09
# 50%    1.611710e+09
# 75%    1.611710e+09
# max    1.611710e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
chart1 = cities_clean.plot.scatter(x='Lat',
                      y='Max Temp',
                      c='LightBlue',edgecolors='DarkBlue', s=50)

plt.title("City Latitude vs Max Temperature (01/23/21)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig('Figure 1.png')

# %% [markdown]
# This plot is measuring the max temperature reading as you move across the latitude range.  You can see the hot, to mild, to cold temparature change as one moved from negative to positive latitude measures.  It looks like I don't have much representation in the negative latitude range to form a more expected low to high to low pattern.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
chart2 = cities_clean.plot.scatter(x='Lat',
                      y='Humidity',
                      c='LightBlue',edgecolors='DarkBlue', s=50)

plt.title("City Latitude vs Humidity (01/23/21)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig('Figure 2.png')

# %% [markdown]
# This plot is measuring the humidity reading as you move across the latitude range.  There doesn't appear to be too much correlation between the lat and humidity readings.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
chart3 = cities_clean.plot.scatter(x='Lat',
                      y='Cloudiness',
                      c='LightBlue',edgecolors='black', s=50)

plt.title("City Latitude vs Cloudiness (01/23/21)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig('Figure 3.png')

# %% [markdown]
# This chart is examining latitude to cloudiness %'s as one moves across the latitude ranges.  Another one with not alot of correlation other than some linear trends occuring across the spectrum.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
chart4 = cities_clean.plot.scatter(x='Lat',
                      y='Wind Speed',
                      c='LightBlue',edgecolors='black', s=50)

plt.title("City Latitude vs Wind Speed (01/23/21)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig('Figure 4.png')

# %% [markdown]
# Another chart examining the measure of wind speeds as one moves across the latitude range.  Not much obvious correlation or clustering here.

# %% [markdown]
# ## Linear Regression

# %%
NorthData = cities_clean[cities_clean['Lat'] > 0] 
SouthData = cities_clean[cities_clean['Lat'] < 0] 
# Equator=cities_clean[cities_clean['Lat'] == 0] 
# Equator

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = NorthData['Lat']
y_values = NorthData['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red", xytext=(0,-20))

plt.title("Northern Hemisphere - Max Temp vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
print(f"The r-squared is: {rvalue**2}")
# print(f'The linear model equation is: {line_eq}')
plt.show()
# Out:
# The r-squared is: 0.7093447149209225

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = SouthData['Lat']
y_values = SouthData['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red", xytext=(-20,60))

plt.title("Southern Hemisphere - Max Temp vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
print(f"The r-squared is: {rvalue**2}")
# print(f'The linear model equation is: {line_eq}')
plt.show()
# Out:
# The r-squared is: 0.1486105979916972

# %% [markdown]
# The two graphs are looking for linear correlation between Latitude measure progress from low to high.  This is why we had to separate the hemisphers.  As you can see there is a strong correlation in the northern hemisphere but not as much in the Southern.  The charts trend as expected, negative as you go warmer to colder in north and warmer as you approach 0 in the Southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = NorthData['Lat']
y_values = NorthData['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red", xytext=(40,20))

plt.title("Northern Hemisphere - Humidity vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
print(f"The r-squared is: {rvalue**2}")
# print(f'The linear model equation is: {line_eq}')
plt.show()
# Out:
# The r-squared is: 0.09940038766291748

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = SouthData['Lat']
y_values = SouthData['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red",xytext=(-25, 20))

plt.title("Southern Hemisphere - Humidity vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
print(f"The r-squared is: {rvalue**2}")
# print(f'The linear model equation is: {line_eq}')
plt.show()
# Out:
# The r-squared is: 0.17628693160317174

# %% [markdown]
# These two charts are looking for linear correlation between humidity and latitude across the two hemispherers.  You find mild correlation across both but the south having over a double r-squared measurement.  This makes sense given the rather randomness of the north plot relative to the south plot.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = NorthData['Lat']
y_values = NorthData['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red",xytext=(10,60))

plt.title("Northern Hemisphere - Cloudiness vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# The r-squared is: 0.07100048213940717

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = SouthData['Lat']
y_values = SouthData['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red", xytext=(-50,60))

plt.title("Southern Hemisphere - Cloudiness vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
print(f"The r-squared is: {rvalue**2}")
# print(f'The linear model equation is: {line_eq}')
plt.show()
# Out:
# The r-squared is: 0.04986591671946732

# %% [markdown]
# As expected from the initial scatter plot, there is not much correlation between cloudiness and either hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = NorthData['Lat']
y_values = NorthData['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="red", xytext=(0,30))

plt.title("Northern Hemisphere - Wind Speed vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
print(f"The r-squared is: {rvalue**2}")
# print(f'The linear model equation is: {line_eq}')
plt.show()
# Out:
# The r-squared is: 0.011573926306692366

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = SouthData['Lat']
y_values = SouthData['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="red", xytext=(-50,25))

plt.title("Southern Hemisphere - Wind Speed vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
print(f"The r-squared is: {rvalue**2}")
# print(f'The linear model equation is: {line_eq}')
plt.show()
# Out:
# The r-squared is: 0.050319921111762624

# %% [markdown]
# Interestingly, practically no correlation between wind and measures in the north but relatively much more in the south.  With that said, there is not strong clustering in either, visually leading to not relying too much on the prediction or correlation.
