# %% [markdown]
# # WeatherPy

# %% [markdown]
# 3 Observable Trends:
# 1. The Northern Hemisphere appears to have colder temperatures thand the Southern.  Even with a light data set for the Southern, at -60 and 60 there is a visual difference.
# 2. Humidity seemed shockingly evenly dispersed across the north and south hemispheres
# 3. There is much stronger correlation in the Northern Hemisphere than Southern when comparing Max Temp and Latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
# !pip install citipy

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities_df=pd.DataFrame(cities)
cities_df.columns=['City']
cities_df.head(5)
# Out:
#           City
# 0       barrow
# 1  new norfolk
# 2   rio blanco
# 3   bredasdorp
# 4     luderitz

# %%
# Add columns for lat, lng, airport name, airport address, airport rating
# Note that we used "" to specify initial entry.

cities_df["Lat"] = ""
cities_df["Lng"] = ""
cities_df["Max Temp"] = ""
cities_df["Humidity"] = ""
cities_df["Cloudiness"] = ""
cities_df["Wind Speed"] = ""
cities_df["Country"] = ""
cities_df["Date"] = ""
cities_df.head()
# Out:
#           City Lat Lng Max Temp Humidity Cloudiness Wind Speed Country Date
# 0       barrow
# 1  new norfolk
# 2   rio blanco
# 3   bredasdorp
# 4     luderitz

# %%
# Declare the URL and units for F
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

# used this below to print JSON for coding the rest

# city='cape town'
# query_url = f"{url}appid={weather_api_key}&units={units}&q="

# response = requests.get(query_url + city).json()
# print(json.dumps(response, indent=4, sort_keys=True))

# %%
# Using the for loop to loop through the data frame cities and write the results back to the data frame

for index, row in cities_df.iterrows():
    query_url = f"{url}appid={weather_api_key}&units={units}&q="
    city=row["City"]
   
      # make request
    response = requests.get(query_url + city).json()
    
    try:           
        cities_df.loc[index, "Lat"] = response["coord"]["lat"]
        cities_df.loc[index, "Lng"] = response["coord"]["lon"]
        cities_df.loc[index, "Max Temp"]= response["main"]["temp_max"]
        cities_df.loc[index, "Humidity"] = response["main"]["humidity"]
        cities_df.loc[index, "Cloudiness"] = response["clouds"]["all"]
        cities_df.loc[index, "Wind Speed"] = response["wind"]["speed"]
        cities_df.loc[index, "Country"] = response["sys"]["country"]
        cities_df.loc[index, "Date"] = response["dt"]
        print(f'Processing Record {index} of Set 1 | {city}')
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

        
cities_df.head()
# Out:
# Processing Record 0 of Set 1 | barrow
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | rio blanco
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | luderitz
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | castro
# Processing Record 8 of Set 1 | bara
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | broome
# Processing Record 13 of Set 1 | aklavik
# Processing Record 14 of Set 1 | nizhniy tsasuchey
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | boyle
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | hualmay
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | chuy
# Processing Record 25 of Set 1 | dingle
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | georgetown
# Missing field/result... skipping.
# Processing Record 31 of Set 1 | cam ranh
# Processing Record 32 of Set 1 | port macquarie
# Processing Record 33 of Set 1 | vardo
# Missing field/result... skipping.
# Processing Record 35 of Set 1 | portland
# Processing Record 36 of Set 1 | amuntai
# Processing Record 37 of Set 1 | tela
# Processing Record 38 of Set 1 | roebourne
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | cherskiy
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | chara
# Processing Record 43 of Set 1 | polovinnoye
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | butaritari
# Missing field/result... skipping.
# Processing Record 48 of Set 1 | coquimbo
# Processing Record 49 of Set 1 | huarmey
# Processing Record 50 of Set 1 | jamestown
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 54 of Set 1 | maniitsoq
# Processing Record 55 of Set 1 | kaitangata
# Processing Record 56 of Set 1 | woodward
# Processing Record 57 of Set 1 | zalegoshch
# Processing Record 58 of Set 1 | gamba
# Processing Record 59 of Set 1 | cap malheureux
# Processing Record 60 of Set 1 | ilulissat
# Processing Record 61 of Set 1 | vaini
# Processing Record 62 of Set 1 | udachnyy
# Processing Record 63 of Set 1 | bathsheba
# Processing Record 64 of Set 1 | ashtabula
# Processing Record 65 of Set 1 | puerto escondido
# Processing Record 66 of Set 1 | tuktoyaktuk
# Processing Record 67 of Set 1 | fairbanks
# Processing Record 68 of Set 1 | margate
# Processing Record 69 of Set 1 | khatanga
# Processing Record 70 of Set 1 | williams lake
# Processing Record 71 of Set 1 | luanda
# Processing Record 72 of Set 1 | cervo
# Processing Record 73 of Set 1 | coihaique
# Processing Record 74 of Set 1 | klaksvik
# Processing Record 75 of Set 1 | berezovyy
# Processing Record 76 of Set 1 | port hardy
# Processing Record 77 of Set 1 | tevaitoa
# Processing Record 78 of Set 1 | saskylakh
# Missing field/result... skipping.
# Processing Record 391 of Set 1 | villa del rosario
# Processing Record 392 of Set 1 | richards bay
# Processing Record 393 of Set 1 | glendive
# Processing Record 394 of Set 1 | totness
# Processing Record 395 of Set 1 | khanpur
# Processing Record 396 of Set 1 | jumla
# Processing Record 397 of Set 1 | paamiut
# Processing Record 398 of Set 1 | bolekhiv
# Processing Record 399 of Set 1 | lavrentiya
# Processing Record 400 of Set 1 | ewa beach
# Processing Record 401 of Set 1 | antofagasta
# Processing Record 402 of Set 1 | lensk
# Processing Record 403 of Set 1 | conceicao do araguaia
# Processing Record 404 of Set 1 | brigantine
# Processing Record 405 of Set 1 | axim
# Processing Record 406 of Set 1 | sao joao da barra
# Processing Record 407 of Set 1 | aljezur
# Processing Record 408 of Set 1 | kyzyl-suu
# Processing Record 409 of Set 1 | kruisfontein
# Missing field/result... skipping.
# Processing Record 411 of Set 1 | loubomo
# Processing Record 412 of Set 1 | meadow lake
# Processing Record 413 of Set 1 | makakilo city
# Processing Record 414 of Set 1 | bensonville
# Processing Record 415 of Set 1 | puerto del rosario
# Processing Record 416 of Set 1 | sampit
# Processing Record 417 of Set 1 | broken hill
# Processing Record 418 of Set 1 | kysyl-syr
# Processing Record 419 of Set 1 | manaure
# Processing Record 420 of Set 1 | shizuishan
# Processing Record 421 of Set 1 | porbandar
# Processing Record 422 of Set 1 | mapimi
# Processing Record 423 of Set 1 | tripoli
# Processing Record 424 of Set 1 | skole
# Processing Record 425 of Set 1 | ponta delgada
# Processing Record 426 of Set 1 | canico
# Processing Record 427 of Set 1 | la trinidad
# Processing Record 428 of Set 1 | gidam
# Processing Record 429 of Set 1 | vilhena
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 432 of Set 1 | staryy nadym
# Processing Record 433 of Set 1 | mvomero
# Processing Record 434 of Set 1 | bozeman
# Processing Record 435 of Set 1 | antalaha
# Processing Record 436 of Set 1 | urengoy
# Processing Record 437 of Set 1 | luang prabang
# Processing Record 438 of Set 1 | hobyo
# Processing Record 439 of Set 1 | esmeralda
# Processing Record 440 of Set 1 | bundi
# Processing Record 441 of Set 1 | adelaide
# Processing Record 442 of Set 1 | estelle
# Processing Record 443 of Set 1 | tungor
# Processing Record 444 of Set 1 | hermosillo
# Processing Record 445 of Set 1 | ludvika
# Processing Record 446 of Set 1 | venezuela
# Processing Record 447 of Set 1 | barranca
# Processing Record 448 of Set 1 | mahibadhoo
# Processing Record 449 of Set 1 | glamoc
# Processing Record 450 of Set 1 | mersing
# Processing Record 451 of Set 1 | yeppoon
# Processing Record 452 of Set 1 | sept-iles
# Processing Record 453 of Set 1 | ust-kulom
# Processing Record 454 of Set 1 | homer
# Processing Record 455 of Set 1 | turinskaya sloboda
# Processing Record 456 of Set 1 | emerald
# Processing Record 457 of Set 1 | ararangua
# Processing Record 458 of Set 1 | nhulunbuy
# Processing Record 459 of Set 1 | coxim
# Processing Record 460 of Set 1 | san marcos
# Missing field/result... skipping.
# Processing Record 462 of Set 1 | kainantu
# Processing Record 463 of Set 1 | harlingen
# Processing Record 464 of Set 1 | ossora
# Processing Record 465 of Set 1 | damietta
# Processing Record 466 of Set 1 | gornopravdinsk
# Processing Record 467 of Set 1 | ozernovskiy
# Processing Record 468 of Set 1 | lubango
# Processing Record 469 of Set 1 | san carlos de bariloche
# Missing field/result... skipping.
# Processing Record 471 of Set 1 | itumbiara
# Processing Record 472 of Set 1 | concepcion del oro
# Processing Record 473 of Set 1 | jieshi
# Processing Record 474 of Set 1 | north battleford
# Processing Record 475 of Set 1 | eureka
# Processing Record 476 of Set 1 | mana
# Processing Record 477 of Set 1 | corinto
# Processing Record 478 of Set 1 | kannur
# Processing Record 479 of Set 1 | tobol
# Processing Record 480 of Set 1 | pirgos
# Processing Record 481 of Set 1 | aksu
# Processing Record 482 of Set 1 | miles city
# Processing Record 483 of Set 1 | clarksburg
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 486 of Set 1 | abaete
# Processing Record 487 of Set 1 | mayumba
# Processing Record 488 of Set 1 | zhezkazgan
# Processing Record 489 of Set 1 | apatou
# Processing Record 490 of Set 1 | queanbeyan
# Processing Record 491 of Set 1 | shimoda
# Missing field/result... skipping.
# Processing Record 493 of Set 1 | altamont
# Processing Record 494 of Set 1 | prince rupert
# Processing Record 495 of Set 1 | quatre cocos
# Processing Record 496 of Set 1 | flin flon
# Processing Record 497 of Set 1 | ulladulla
# Processing Record 498 of Set 1 | ormara
# Processing Record 499 of Set 1 | mackay
# Processing Record 500 of Set 1 | morant bay
# Processing Record 501 of Set 1 | inuvik
# Processing Record 502 of Set 1 | samarinda
# Processing Record 503 of Set 1 | mtimbira
# Processing Record 504 of Set 1 | neiafu
# Processing Record 505 of Set 1 | kidal
# Processing Record 506 of Set 1 | labuhan
# Processing Record 507 of Set 1 | grand forks
# Processing Record 508 of Set 1 | rio branco
# Processing Record 509 of Set 1 | longyearbyen
# Processing Record 510 of Set 1 | togur
# Processing Record 511 of Set 1 | aguimes
# Processing Record 512 of Set 1 | zhangye
# Processing Record 513 of Set 1 | batavia
# Processing Record 514 of Set 1 | lingao
# Processing Record 515 of Set 1 | marsh harbour
# Processing Record 516 of Set 1 | bundaberg
# Processing Record 517 of Set 1 | tazovskiy
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 520 of Set 1 | shawnee
# Processing Record 521 of Set 1 | northam
# Processing Record 522 of Set 1 | kingaroy
# Processing Record 523 of Set 1 | pozo colorado
# Processing Record 524 of Set 1 | namibe
# Processing Record 525 of Set 1 | vlasikha
# Processing Record 526 of Set 1 | shangzhi
# Missing field/result... skipping.
# Processing Record 528 of Set 1 | mormugao
# Processing Record 529 of Set 1 | kloulklubed
# Processing Record 530 of Set 1 | jatai
# Processing Record 531 of Set 1 | egvekinot
# Processing Record 532 of Set 1 | eenhana
# Processing Record 533 of Set 1 | port hueneme
# Missing field/result... skipping.
# Processing Record 535 of Set 1 | kayes
# Processing Record 536 of Set 1 | cabatuan
# Processing Record 537 of Set 1 | parnamirim
# Processing Record 538 of Set 1 | koumra
# Processing Record 539 of Set 1 | akalkot
# Processing Record 540 of Set 1 | qesarya
# Processing Record 541 of Set 1 | juruti
# Processing Record 542 of Set 1 | malaya serdoba
# Missing field/result... skipping.
# Processing Record 544 of Set 1 | leshukonskoye
# Missing field/result... skipping.
# Processing Record 546 of Set 1 | alofi
# Processing Record 547 of Set 1 | samarai
# Processing Record 548 of Set 1 | bilma
# Missing field/result... skipping.
# Processing Record 550 of Set 1 | nizhniy kuranakh
# Processing Record 551 of Set 1 | loandjili
# Processing Record 552 of Set 1 | port moresby
# Processing Record 553 of Set 1 | skelleftea
# Processing Record 554 of Set 1 | shambu
# Processing Record 555 of Set 1 | nantucket
# Processing Record 556 of Set 1 | banjar
# Processing Record 557 of Set 1 | la ronge
# Processing Record 558 of Set 1 | haysville
# Processing Record 559 of Set 1 | russell
# Processing Record 560 of Set 1 | omboue
# Processing Record 561 of Set 1 | ribeira brava
# Processing Record 562 of Set 1 | tarata
# Processing Record 563 of Set 1 | vila velha
# Processing Record 564 of Set 1 | kologriv
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 567 of Set 1 | leningradskiy
# Processing Record 568 of Set 1 | gornyye klyuchi
# Processing Record 569 of Set 1 | hilton head island
# Missing field/result... skipping.
# Processing Record 571 of Set 1 | cartagena
# Processing Record 572 of Set 1 | tonantins
# Missing field/result... skipping.
# Processing Record 574 of Set 1 | kirkuk
# Processing Record 575 of Set 1 | suntar
# Processing Record 576 of Set 1 | youkounkoun
# Processing Record 577 of Set 1 | paris
# Processing Record 578 of Set 1 | doha
# Processing Record 579 of Set 1 | dhandhuka
# Processing Record 580 of Set 1 | smithers
# Processing Record 581 of Set 1 | haapiti
# Processing Record 582 of Set 1 | arman
# Processing Record 583 of Set 1 | byron bay
# Processing Record 584 of Set 1 | kundiawa
# Processing Record 585 of Set 1 | gafanha da nazare
# Processing Record 586 of Set 1 | vanimo
# Missing field/result... skipping.
# Processing Record 588 of Set 1 | vila
# Processing Record 589 of Set 1 | manati
# Processing Record 590 of Set 1 | snina
# Processing Record 591 of Set 1 | buchanan
# Missing field/result... skipping.
# Processing Record 593 of Set 1 | kahului
# Processing Record 594 of Set 1 | natchitoches
# Processing Record 595 of Set 1 | chunskiy
# Processing Record 596 of Set 1 | tiznit
# Processing Record 597 of Set 1 | emirdag
# Missing field/result... skipping.
# Processing Record 599 of Set 1 | kaabong
# Processing Record 600 of Set 1 | arlit
# Processing Record 601 of Set 1 | christchurch
# Missing field/result... skipping.
# Processing Record 603 of Set 1 | peniche
# Processing Record 604 of Set 1 | staicele
# Processing Record 605 of Set 1 | diego de almagro
# Processing Record 606 of Set 1 | alta floresta
# Processing Record 607 of Set 1 | lobito
# Processing Record 608 of Set 1 | kharitonovo
# Processing Record 609 of Set 1 | taoudenni
# Processing Record 610 of Set 1 | dzaoudzi
# Processing Record 611 of Set 1 | luganville
# Processing Record 612 of Set 1 | krasnoarmeyskiy
# Processing Record 613 of Set 1 | emba
# Missing field/result... skipping.
# Processing Record 615 of Set 1 | barcelona
# Processing Record 616 of Set 1 | beringovskiy
# Processing Record 617 of Set 1 | bac lieu
# Processing Record 618 of Set 1 | fuerte olimpo
# Processing Record 619 of Set 1 | tual
# Processing Record 620 of Set 1 | behshahr
# Processing Record 621 of Set 1 | le mars
#           City      Lat      Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0       barrow  71.2906 -156.789     -9.4       77         90       5.75
# 1  new norfolk -42.7826  147.059       59       53         63       1.99
# 2   rio blanco  18.8333   -97.15    68.72       70         42       7.27
# 3   bredasdorp -34.5322  20.0403     55.4       76         86       5.75
# 4     luderitz -26.6481  15.1594    67.71       61          0      27.29
#
#   Country        Date
# 0      US  1611788939
# 1      AU  1611788939
# 2      MX  1611788940
# 3      ZA  1611788941
# 4      NA  1611788942

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.to_csv("City_data.csv")
cities_df.head(5)
# cities_df.to_numeric("Lat")
# Out:
#           City      Lat      Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0       barrow  71.2906 -156.789     -9.4       77         90       5.75
# 1  new norfolk -42.7826  147.059       59       53         63       1.99
# 2   rio blanco  18.8333   -97.15    68.72       70         42       7.27
# 3   bredasdorp -34.5322  20.0403     55.4       76         86       5.75
# 4     luderitz -26.6481  15.1594    67.71       61          0      27.29
#
#   Country        Date
# 0      US  1611788939
# 1      AU  1611788939
# 2      MX  1611788940
# 3      ZA  1611788941
# 4      NA  1611788942

# %%
# Converting to numbers to analyze further

cities_df['Lat']=pd.to_numeric(cities_df['Lat'],errors='coerce')
cities_df['Lng']=pd.to_numeric(cities_df['Lng'],errors='coerce')
cities_df['Max Temp']=pd.to_numeric(cities_df['Max Temp'],errors='coerce')
cities_df['Humidity']=pd.to_numeric(cities_df['Humidity'],errors='coerce')
cities_df['Cloudiness']=pd.to_numeric(cities_df['Cloudiness'],errors='coerce')
cities_df['Wind Speed']=pd.to_numeric(cities_df['Wind Speed'],errors='coerce')
cities_df['Date']=pd.to_numeric(cities_df['Date'],errors='coerce')
# cities_df.dtypes

# %%
cities_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  573.000000  573.000000  573.000000  573.000000  573.000000  573.000000
# mean    18.483542   14.725264   49.681536   73.748691   53.408377    8.531483
# std     33.248711   93.254689   32.772996   18.476493   40.263738    5.846128
# min    -54.800000 -179.166700  -53.190000   14.000000    0.000000    0.160000
# 25%     -9.800000  -68.514500   30.180000   65.000000    6.000000    3.530000
# 50%     21.100000   18.966700   62.600000   78.000000   60.000000    7.160000
# 75%     46.090100   99.634200   75.580000   87.000000   91.000000   11.790000
# max     78.218600  179.316700   89.400000  100.000000  100.000000   32.990000
#
#                Date
# count  5.730000e+02
# mean   1.611789e+09
# std    6.835518e+01
# min    1.611789e+09
# 25%    1.611789e+09
# 50%    1.611789e+09
# 75%    1.611789e+09
# max    1.611789e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Check for cities that have humidity over 100%, return the index if so

index_names = cities_df[(cities_df['Humidity'] > 100)].index
index_names
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "cities_clean".

cities_clean=cities_df.drop(index_names, inplace = False)
cities_clean.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  573.000000  573.000000  573.000000  573.000000  573.000000  573.000000
# mean    18.483542   14.725264   49.681536   73.748691   53.408377    8.531483
# std     33.248711   93.254689   32.772996   18.476493   40.263738    5.846128
# min    -54.800000 -179.166700  -53.190000   14.000000    0.000000    0.160000
# 25%     -9.800000  -68.514500   30.180000   65.000000    6.000000    3.530000
# 50%     21.100000   18.966700   62.600000   78.000000   60.000000    7.160000
# 75%     46.090100   99.634200   75.580000   87.000000   91.000000   11.790000
# max     78.218600  179.316700   89.400000  100.000000  100.000000   32.990000
#
#                Date
# count  5.730000e+02
# mean   1.611789e+09
# std    6.835518e+01
# min    1.611789e+09
# 25%    1.611789e+09
# 50%    1.611789e+09
# 75%    1.611789e+09
# max    1.611789e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
chart1 = cities_clean.plot.scatter(x='Lat',
                      y='Max Temp',
                      c='LightBlue',edgecolors='DarkBlue', s=50)

plt.title("City Latitude vs Max Temperature (01/23/21)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig('Figure 1.png')

# %% [markdown]
# This plot is measuring the max temperature reading as you move across the latitude range.  You can see the mild, to hot, to cold temparature change as one moved from negative to positive latitude measures.  It looks like I don't have much representation in the negative latitude range to form a more expected low to high to low pattern.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
chart2 = cities_clean.plot.scatter(x='Lat',
                      y='Humidity',
                      c='LightBlue',edgecolors='DarkBlue', s=50)

plt.title("City Latitude vs Humidity (01/23/21)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig('Figure 2.png')

# %% [markdown]
# This plot is measuring the humidity reading as you move across the latitude range.  There doesn't appear to be too much correlation between the lat and humidity readings.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
chart3 = cities_clean.plot.scatter(x='Lat',
                      y='Cloudiness',
                      c='LightBlue',edgecolors='black', s=50)

plt.title("City Latitude vs Cloudiness (01/23/21)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig('Figure 3.png')

# %% [markdown]
# This chart is examining latitude to cloudiness %'s as one moves across the latitude ranges.  Another one with not alot of correlation other than some linear trends occuring across the spectrum.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
chart4 = cities_clean.plot.scatter(x='Lat',
                      y='Wind Speed',
                      c='LightBlue',edgecolors='black', s=50)

plt.title("City Latitude vs Wind Speed (01/23/21)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig('Figure 4.png')

# %% [markdown]
# Another chart examining the measure of wind speeds as one moves across the latitude range.  Not much obvious correlation or clustering here.

# %% [markdown]
# ## Linear Regression

# %%
# Creating north and south dataframes

NorthData = cities_clean[cities_clean['Lat'] > 0] 
SouthData = cities_clean[cities_clean['Lat'] < 0] 
# Equator=cities_clean[cities_clean['Lat'] == 0] 
# Equator

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# this commenting applies across the remaining regression charts

# setting the values
x_values = NorthData['Lat']
y_values = NorthData['Max Temp']

# declaring the linear regression process
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

# creating the linear line equation for printing
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# creating the scatter plots 
plt.scatter(x_values,y_values)

# creating the line and printing the y equation for it
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red", xytext=(0,-20))

# format, print the r squared, print the chart
plt.title("Northern Hemisphere - Max Temp vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# The r-squared is: 0.7401382567604333

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = SouthData['Lat']
y_values = SouthData['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red", xytext=(-20,60))

plt.title("Southern Hemisphere - Max Temp vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# The r-squared is: 0.3801095463739856

# %% [markdown]
# The two graphs are looking for linear correlation between Latitude measure progress from low to high.  This is why we had to separate the hemisphers.  As you can see there is a strong correlation in the northern hemisphere but not as much in the Southern.  The charts trend as expected, negative as you go warmer to colder in north and warmer as you approach 0 in the Southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = NorthData['Lat']
y_values = NorthData['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red", xytext=(40,20))

plt.title("Northern Hemisphere - Humidity vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# The r-squared is: 0.08440486613006673

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = SouthData['Lat']
y_values = SouthData['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red",xytext=(-25, 20))

plt.title("Southern Hemisphere - Humidity vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
print(f"The r-squared is: {rvalue**2}")
# print(f'The linear model equation is: {line_eq}')
plt.show()
# Out:
# The r-squared is: 0.12855711133116546

# %% [markdown]
# These two charts are looking for linear correlation between humidity and latitude across the two hemispherers.  You find mild correlation across both but the south having over a double r-squared measurement.  This makes sense given the rather randomness of the north plot relative to the south plot.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = NorthData['Lat']
y_values = NorthData['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red",xytext=(10,60))

plt.title("Northern Hemisphere - Cloudiness vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# The r-squared is: 0.09043886828812994

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = SouthData['Lat']
y_values = SouthData['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red", xytext=(-50,60))

plt.title("Southern Hemisphere - Cloudiness vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
print(f"The r-squared is: {rvalue**2}")
# print(f'The linear model equation is: {line_eq}')
plt.show()
# Out:
# The r-squared is: 0.0384771172686729

# %% [markdown]
# As expected from the initial scatter plot, there is not much correlation between cloudiness and either hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = NorthData['Lat']
y_values = NorthData['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="red", xytext=(0,30))

plt.title("Northern Hemisphere - Wind Speed vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
print(f"The r-squared is: {rvalue**2}")
# print(f'The linear model equation is: {line_eq}')
plt.show()
# Out:
# The r-squared is: 0.0026541353477418073

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = SouthData['Lat']
y_values = SouthData['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="red", xytext=(-50,25))

plt.title("Southern Hemisphere - Wind Speed vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
print(f"The r-squared is: {rvalue**2}")
# print(f'The linear model equation is: {line_eq}')
plt.show()
# Out:
# The r-squared is: 0.20174224466216564

# %% [markdown]
# Interestingly, practically no correlation between wind and measures in the north but relatively much more in the south.  With that said, there is not strong clustering in either, visually leading to not relying too much on the prediction or correlation.
